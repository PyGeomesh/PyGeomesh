# %%
from Geometry import Point
from matplotlib import pyplot as plt

point = Point([0, 0, 0], 2)
points = point.random_points(50000)
print(points.shape)

ax = plt.figure(figsize=(10, 10)).add_subplot(111, projection='3d')

ax.scatter(
    points[:, 0],
    points[:, 1],
    points[:, 2],
    s=0.1,
    c='r',
)
# Out:
# (50000, 3)

# %%
boundary_points = point.random_points_on_boundary(n=3000)
ax = plt.figure(figsize=(10, 10)).add_subplot(111, projection='3d')
ax.scatter(
    boundary_points[:, 0],
    boundary_points[:, 1],
    boundary_points[:, 2],
    s=0.1,
    c='r',
)

# %%
point = Point([0, 0], 4)
points = point.random_points(5000)
print(points.shape)
plt.figure(figsize=(10, 10))
plt.scatter(points[:, 0], points[:, 1], s=0.5, c='r')
# Out:
# (5000, 2)

# %%
boundary_points = point.random_points_on_boundary(n=300)
print(boundary_points.shape)
plt.figure(figsize=(10, 10))
plt.scatter(boundary_points[:, 0], boundary_points[:, 1], s=0.5, c='r')
# Out:
# (300, 2)
